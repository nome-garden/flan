# %% [markdown]
# # Q1

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(0,3,100) #linspace makes an array 0-3 with 100 data points
yerr=0.05+2*x #y-error for error bars

plt.figure()
plt.title('exponential plots')
plt.xlabel('x values')
plt.ylabel('exponents')

#plt.plot(x,x**2,label='x^2')
#plt.plot(x,x**3,label='x^3')
#plt.plot(x,x**4,label='x^4')
#plt.plot(x,x**5,label='x^5')

for n in range (2,6): #an easier way to do the above is making a for loop
    #plt.plot(x,x**n, label='x^'+str(n))
    plt.errorbar(x,x**n,yerr=yerr, label='x^'+str(n)) #errorbar is a plot in itself, so either use plt.plot or plt.errorbar with error bars

plt.legend() #creates a legend based on the labels
plt.show()

# %% [markdown]
# # Q2

# %%
x=np.linspace(0,5,100)

y1=np.exp(x)
y2=np.exp(2*x)
y3=np.exp(x)+1
y4=np.exp(x)-1

fig,axs=plt.subplots(2,2)

axs[0,0].plot(x,y1)
axs[0,1].plot(x,y2)
axs[1,0].plot(x,y3)
axs[1,1].plot(x,y4)

plt.tight_layout() #makes it so the axes digits don't overlap each other
plt.show()

# %% [markdown]
# # Q3

# %%
img_data=np.loadtxt('astro_image.csv')


plt.figure()
plt.imshow(img_data,cmap='inferno',vmin=50,vmax=400, origin ='upper')
#vmin and max create a max and min to exclude outliers; rescales data to make it more visible
#origin changes the way the y-axes run (but the image is upside down when origin='lower')
plt.colorbar()
plt.show()

# %%
import os
os.chdir('plotting_dis')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 2
#       1 import os
# ----> 2 os.chdir('plotting_dis')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'plotting_dis'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\roost\\flan\\dis\\plotting_dis'

# %%
os.listdir()
# Out:
# ['astro_image.csv', 'plot discussion.ipynb']
